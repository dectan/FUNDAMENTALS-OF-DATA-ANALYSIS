# %% [markdown]
# # Fundamentals of Data Analysis Tasks
#
# **Declan Tannian**
#
# ***

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1
#
# > The Collatz conjecture is a famous unsolved problem in mathematics. The problem is to prove that if you start with any positive
# integer x and repeatedly apply the function $f(x)$ below, you always get stuck in the repeating sequence 1, 4, 2, 1, 4, 2, . . .
# f(x) =
# x ÷ 2 if x is even
# 3x + 1 otherwise
# For example, starting with the value 10, which is an even number, we divide it by 2 to get 5. Then 5 is an odd number so, we multiply by 3 and add 1 to get 16. Then we repeatedly divide by 2 to get 8, 4, 2, 1. Once we are at 1, we go back to 4 and get stuck in the repeating sequence 4, 2, 1 as we suspected.
# Your task is to verify, using Python, that the conjecture is true for the first 10,000 positive integers.
#
# https://stackoverflow.com/questions/13366830/collatz-conjecture-sequence

# %%
def collatz_sequence(x):
    seq = [x]
    while x > 1:
        if x % 2 == 0:
            x = x // 2
        else:
            x = 3 * x + 1
        seq.append(x)
    return seq

# %%
# check values 1 - 10000
for i in range(1, 10001):
    seq = collatz_sequence(i)
    #check if sequence ends with 1 and proves/disproves Collatz
    if seq[-1] != 1:
        print(f"Collatz conjecture is false for {i}")
    else:
        print(f"Collatz conjecture is true for {i}")

# %%
#collatz(100)

# %% [markdown]
# *** Task 2 ***

# %% [markdown]
#  The variables in the penguin dataset are as follows:
#  1. Categorical variables: take on a limited number of values and represent categories. Examples include species, island, sex.
#  2. Numerical variables: take on numerical values. Examples include bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g,

# %% [markdown]
# The Penguin dataset is included in Seaborn, so have imported in order to access this dataset. I checked which datasets were available by using sns.get_dataset_names(). I selected penguin dataset by using df = sns.load_dataset('penguins'). To check the current version I used sns.__version__ to dispaly current version. To display the top 5 rows I used df.head

# %%
sns.__version__

# %%
df = sns.load_dataset('penguins')
df.head()

# %%
df.describe()

# %%
df.shape

# %% [markdown]
# *** Task 3 ***

# %% [markdown]
# There are 7 varaibles in this dataset. As mentioned above, there are Categorical variables like species, island, sex, and Numerical variables like bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, year.
#
# 1. species , this a categorical variable. This would be best suited to categorical distribution (also called  generalized Bernoulli distribution, multinoulli distribution)
# https://en.wikipedia.org/wiki/Categorical_distribution. This describes the possible results of a random variable that can be one of k possible categories, with the probaility of of each category seperately specified.
# 2. island , https://www.statisticshowto.com/multinomial-distribution/ binomial distribution.
# 3. sex , https://byjus.com/maths/binomial-distribution/  modelled using Binomial probability distribution.only 2 possible outcomes.
# 4. bill_length_mm, normal distribution https://www.scribbr.com/statistics/probability-distributions/, assumes that the variable is evenly distributed
# 5. bill_depth_mm, normal distribution assumes that the variable is evenly distributed
# 6. flipper_length_mm, normal distribution
# 7. body_mass_g, normal distribution

# %% [markdown]
# *** Task 4 ***

# %%
# range of p values
pvalues = np.linspace(0,1,100)

entropy_values = []

for p in pvalues:

    p0 = (1 - p) ** 2
    p1 = 2 * p * (1 - p)
    p2 = p ** 2
    
    # Entropy calculation
    entropy = -(p0 * np.log2(p0) + p1 * np.log2(p1) + p2 * np.log2(p2))
    entropy_values.append(entropy)

# %%
plt.plot(pvalues, entropy_values, label="Entropy")
plt.xlabel("Probability (p)")
plt.ylabel("Entropy")
plt.title("Entropy of Total Heads vs. Probability")
plt.legend()
plt.show()

# %% [markdown]
# ***
# # End
