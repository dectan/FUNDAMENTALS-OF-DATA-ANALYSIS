# %% [markdown]
# # Fundamentals of Data Analysis Tasks
#
#
# ***

# %% [markdown]
# ![ATU Galway](https://www.atu.ie/sites/default/files/styles/homepage_hero/public/2022-03/GMIT-Galway-Campus.jpg?itok=JshYufwh "ATU Galway")
# <img src="https://www.atu.ie/sites/default/files/styles/homepage_hero/public/2022-03/GMIT-Galway-Campus.jpg" width=800 /> ![](https://www.atu.ie/sites/default/files/styles/homepage_hero/public/2022-03/GMIT-Galway-Campus.jpg)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1
#
# > The Collatz conjecture is a famous unsolved problem in mathematics. The problem is to prove that if you start with any positive
# integer x and repeatedly apply the function $f(x)$ below, you always get stuck in the repeating sequence 1, 4, 2, 1, 4, 2, . . .
# f(x) =
# x ÷ 2 if x is even
# 3x + 1 otherwise
# For example, starting with the value 10, which is an even number, we divide it by 2 to get 5. Then 5 is an odd number so, we multiply by 3 and add 1 to get 16. Then we repeatedly divide by 2 to get 8, 4, 2, 1. Once we are at 1, we go back to 4 and get stuck in the repeating sequence 4, 2, 1 as we suspected.
# Your task is to verify, using Python, that the conjecture is true for the first 10,000 positive integers.

# %% [markdown]
# Initial code sourced here [1] https://stackoverflow.com/questions/13366830/collatz-conjecture-sequence

# %%
def collatz_sequence(x):
    seq = [x]
    while x > 1:
        if x % 2 == 0:
            x = x // 2
        else:
            x = 3 * x + 1
        seq.append(x)
    return seq

# %%
# check values 1 - 10000
for i in range(1, 10001):
    seq = collatz_sequence(i)
    #check if sequence ends with 1 and proves/disproves Collatz, display output in 100 intervals using and statement
    if (seq[-1] == 1 and  i % 1000 == 0):
        print(f"Collatz conjecture is True for {i}")
        
    elif seq[-1] != 1:
        print(f"Collatz conjecture is not true for {i}")
        break
# Out:
# Collatz conjecture is True for 1000
# Collatz conjecture is True for 2000
# Collatz conjecture is True for 3000
# Collatz conjecture is True for 4000
# Collatz conjecture is True for 5000
# Collatz conjecture is True for 6000
# Collatz conjecture is True for 7000
# Collatz conjecture is True for 8000
# Collatz conjecture is True for 9000
# Collatz conjecture is True for 10000

# %% [markdown]
# # Task 2
#
# Give an overview of the famous penguins data set, explaining the types of variables it contains. Suggest the types of variables that should be used to model them in Python, explaining your rationale

# %% [markdown]
# The Penguin dataset is included in Seaborn, so I have imported in order to access this dataset. I checked which datasets were available by using sns.get_dataset_names(). I selected penguin dataset by using df = sns.load_dataset('penguins'). To check the current version I used sns.__version__ to dispaly current version.

# %%
df = sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.__version__
# Out:
# '0.11.2'

# %% [markdown]
# The Palmer Penguins dataset is a popular dtaset that captures data on three different species of penguins. By using *df.shape* below, we can see this dataset contains 344 rows and 7 columns. By running *.unique* below for species and islands and sex, we can see the unique species is Adelie Chinstrap and Gentoo. The unique islands are Torgersen, Biscoe and Dream. The columns are as follows;
#
# 1. species: There are three different species of penguin's, which are Adelie, Gentoo and Chinstrap
# 2. island: There are 3 islands which penguin's were observed, which are Torgersen, Biscoe and Dream
# 3. bill length_mm: The length os the penguin's bill in millimetres
# 4. bill depth_mm: The depth os the penguin's bill in millimetres
# 5. flipper_length_mm: The length of the penguin's flipper in millimetres
# 6. body_mass_g: The body mass of penguin's in grams
# 7. sex: The sex of the penguins , either male or female

# %% [markdown]
# Variable types
#
# ![ATU Galway](https://i0.wp.com/prinsli.com/wp-content/uploads/2019/01/variable-in-statistics.png "ATU Galway")

# %% [markdown]
# ![texte]("https://i0.wp.com/prinsli.com/wp-content/uploads/2019/01/variable-in-statistics.png")

# %% [markdown]
# There are both categorical and numerical variables in the penguin dataset. qualitative variables are categorical while quantative are numerical. From the .info code , I can see that 4 of the variables are numeric type and 3 variables are categorical.[2] https://statisticseasily.com/quantitative-vs-qualitative/
# A quantitive variable variable can be continuous or discrete. If its value is obtained by measuring it, then it is continuous.[3] https://en.wikipedia.org/wiki/Continuous_or_discrete_variable#:~:text=A%20continuous%20variable%20is%20a%20variable%20whose%20value,can%20take%20on%20any%20value%20in%20that%20range.
#
#
# 1. species: this is a categorical variable, ie there is a finite number of possible values
# 2. island: this is a categorical variable, ie there is a finite number of possible values.
# 3. bill length_mm: This is a numerical variable, ie there is a continious range of possible values.
# 4. bill depth_mm: This is a numerical variable, ie there is a continious range of possible values
# 5. flipper_length_mm: This is a numerical variable, ie there is a continious range of possible values
# 6. body_mass_g: This is a numerical variable, ie there is a continious range of possible values
# 7. sex: this is a categorical variable, ie there is a finite number of possible values
#
# 1. species: Qualative variable
# 2. island: Qualative variable.
# 3. bill length_mm: Quantative.
# 4. bill depth_mm: Quantative
# 5. flipper_length_mm: Quantative
# 6. body_mass_g: Quantative
# 7. sex: Qualative variable

# %% [markdown]
# There are 4 levels of measurement (Nominal, Ordinal, Interval and Ratio)[4] https://www.scribbr.com/statistics/levels-of-measurement/
#
# * Nominal: data can only be categorised
# * Ordinal: data can be categorised and ranked
# * Interval: the data can be categorized, ranked, and evenly spaced
# * Ratio: the data can be categorized, ranked, evenly spaced, and has a natural zero.

# %% [markdown]
# There are two primary categories of categorical data:
#
# Nominal data: This is the data category that names or labels its categories. It has features resembling a noun and is occasionally referred to as naming data.
# Ordinary data: Elements with rankings, orders, or rating scales are included in this category of categorical data. Nominal data can be ordered and counted but not measured.[5] https://www.questionpro.com/blog/categorical-data-vs-numerical-data/

# %% [markdown]
# Nominal and ratio data types are both used to describe categorical variables. The difference between the two data types is that ordinal data has ordered categories and nominal data does not.
#
# Interval and ratio data types are both used to describe numeric variables. The key difference is that ratio data has a “true zero”. In other words, a value of zero signifies that the variable you’re describing doesn’t exist. Weight is an example of ratio data because if an object weighs zero pounds, it is weightless. Temperature in degrees Fahrenheit is an example of interval data because a temperature of zero degrees just means it’s really cold, not that the temperature doesn’t exist. [6] https://libanswers.lib.miamioh.edu/stats-faq/faq/343638#:~:text=Nominal%20and%20ratio%20data%20types%20are%20both%20used,types%20are%20both%20used%20to%20describe%20numeric%20variables.

# %% [markdown]
# 1. species: nominal variable as the order of the values do not matter
# 2. island: nominal variable as the order of the values do not matter
# 3. bill length_mm: interval variable as the difference between two values is importantant but the ratio isn't.
# 4. bill depth_mm: interval variable as the difference between two values is importantant but the ratio isn't.
# 5. flipper_length_mm: interval variable as the difference between two values is importantant but the ratio isn't.
# 6. body_mass_g: ratio variable which means the differnece and ratio between two value are important.
# 7. sex: nominal variable as the order of the values do not matter

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [markdown]
# When chosing the type of variable is critical to ensure the collected data is accurate and in the correct form and easy to work with.
#
# 1. species: type object. a categorical variable that stores string which can be observed but not measured. String is default datatype for categorical variables in Pandas.
# 2. island: type object. a categorical variable that stores string which can be observed but not measured. String is default datatype for categorical variables in Pandas..
# 3. bill length_mm: float64  should be modelled as a numerical variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations or for graphs , like scatter plots etc.
# 4. bill depth_mm: float64 should be modelled as a numerical variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations or for graphs , like scatter plots etc.
# 5. flipper_length_mm: float64 should be modelled as a numerical variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations or for graphs , like scatter plots etc.
# 6. body_mass_g: float64 should be modelled as a numerical variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations or for graphs , like scatter plots etc.
# 7. sex: type object. a categorical variable that stores string which can be observed but not measured. String is default datatype for categorical variables in Pandas.

# %% [markdown]
# To summarise the above information, I have created the following table.
#
# | species | island | bill_length_mm | bill_depth_mm| flipper_length_mm| body_mass_g| sex|
# | --- | --- | --- | --- | --- | --- | --- |
# | categorical | categorical | numerical | numerical | numerical | numerical | categorical |
# | qualitative | qualitative | quantative | quantative |quantative | quantative | qualitative |
# | categorical | continuous | continuous | continuous | continuous | continuous | categorical |
# | nominal scale | nominal scale | interval scale | interval scale | interval scale | ratio scale | nominal scale |
# | string | string | float | float | float | float | string |

# %% [markdown]
# The rationale for chosing the above type of variables is to ensure the data type correctly suits the ariable. This allows for easy manipulation and ananlysis of variables in the dataset.

# %%
df.shape
# Out:
# (344, 7)

# %% [markdown]
# # Task 3
#
# continuous probability distribution /discrete
#
# For each of the variables in the penguins data set, suggest what probability distribution from the numpy random distributions list is the most appropriate to model the variable.

# %% [markdown]
# There are 7 varaibles in this dataset. As mentioned above, there are Categorical variables like species, island, sex, and Numerical variables like bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, year.
#
# 1. species , this a categorical variable with three possible values: Adelie, Chinstrap and Gentoo. A suitable distribution to model this variable would be *numpy.random.choice*, which can genereate random samples from a discrete set of choices. [7]  https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html The frequency of each species can be captured and assigned when synthesising new data. https://www.sharpsightlabs.com/blog/numpy-random-choice/
#
# 2. island , is a categorical variable. A suitable distribution would also be *numpy.random.choice* to genereate random samples from a discrete set of choices.[8] https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html The frequency of each species can be captured and assigned when synthesising new data.[9] https://www.sharpsightlabs.com/blog/numpy-random-choice/
#
# 3. sex , is a categorical variable with two possible outcome: male and female. A suitable distribution would be *numpy.random.binomial* [10] https://byjus.com/maths/binomial-distribution/  modelled using Binomial probability distribution is a discrete proobability distribution with only 2 possible outcomes. [11] https://byjus.com/maths/binomial-distribution/
#
# 4. bill_length_mm, is a numerical variable with continious values. A suitable distribution for this variable would be *numpy.random.normal* which generates random samples from a normal(Gausson) distribution)normal distribution. From examining this variable in the plot, we can see it is roughly bell shaped and matches expected outcome of normal distribution. [12] https://www.w3schools.com/python/numpy/numpy_random_normal.asp By using the *mean* as an input, we captures the centre of the data to align synthesised data with original data.[13] https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# 5. bill_depth_mm, is a numerical variable with continious values. A suitable distribution for this variable would be *numpy.random.normal* which generates random samples from a normal(Gausson) distribution)normal distribution. From examining this variable in the plot below, we can see it is roughly bell shaped and matches expected outcome of normal distribution. [14] https://www.w3schools.com/python/numpy/numpy_random_normal.asp By using the *mean* as an input, we captures the centre of the data to align synthesised data with original data. [15] https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# 6. flipper_length_mm, is a numerical variable with continious values. A suitable distribution for this variable would be *numpy.random.uniform* which generates random samples from a uniform distribution.
#
# 7. body_mass_g, is a numerical variable with continious values. A suitable distribution for this variable would be *numpy.random.weibull* which generates random samples from a Weibull distribution. From examining this variable in the plot below, we can see the data is skewed. The Weibull distribution is a continious probability distribution and it  is used to model skewed. Its flexibility allows for both left and right skewed data.

# %% [markdown]
# ![WeibullDistribution](https://blog.minitab.com/hubfs/Imported_Blog_Media/weibull_distribution_3.gif?t=1537556350140 "Weibull Distribution")

# %%
plt.hist(df['species'], bins=10)
plt.title('Species')
plt.xlabel("species")
plt.ylabel("count")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist(df['island'], bins=10)
plt.title('islands')
plt.xlabel("island")
plt.ylabel("count")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.kdeplot(df['bill_length_mm'],shade=True, label="bill_length_mm")
plt.title('bill_length_mm')
plt.xlabel("mm")
plt.ylabel("count")
plt.legend()
plt.show()

# %%
sns.kdeplot(df['bill_depth_mm'],shade=True, label="bill_depth_mm")
plt.title('bill_depth_mm')
plt.xlabel("mm")
plt.ylabel("count")
plt.legend()
plt.show()

# %%
sns.kdeplot(df['flipper_length_mm'],shade=True, label="flipper_length_mm")
plt.title('flipper_length_mm')
plt.xlabel("mm")
plt.ylabel("count")
plt.legend()
plt.show()

# %%
sns.kdeplot(df['body_mass_g'],shade=True, label="body_mass_g")
plt.title('body_mass_g')
plt.xlabel("mm")
plt.ylabel("count")
plt.legend()
plt.show()

# %%
df = df.dropna(subset=["sex"])
plt.hist(df["sex"], bins=10, color="blue")
plt.title('sex')
plt.xlabel("sex")
plt.ylabel("count")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Task 4

# %% [markdown]
# Suppose you are flipping two coins, each with a probability p of giving heads. Plot the entropy of the total number of heads versus p

# %%
def H(p):
    return -(1-p) * np.log2(1.0 - p)- p *np.log2(p)

# %%
H(.5)
# Out:
# 1.0

# %%
fig, ax = plt.subplots(figsize=(12, 6),label = "Entropy")

p = np.linspace(0.00000001,0.9999999,10001)
# flip 2 coins
ax.plot(p,H(p*2));
plt.xlabel("Probability (p)")
plt.ylabel("Entropy")
plt.title("Entropy of Total Heads vs. Probability for 2 coins")
plt.show()
# Out:
# C:\Users\irivyo\AppData\Local\Temp\ipykernel_20240\2990280497.py:2: RuntimeWarning: invalid value encountered in log2
#   return -(1-p) * np.log2(1.0 - p)- p *np.log2(p)

# %% [markdown]
# # Task 5
# Create an appropriate individual plot for each of the variables in the penguin data set.

# %% [markdown]
# ### Brief overview of plots used
#
# * Histograms [16] https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/ are a fundamental tool in data visualisation and provides a graphical dispaly of the distribution of data.  They are commonly used when analyzing continuous data. The x- axis represents the bin ranges and the y-axis gives information on the frequency.
#
# * Box plots [17] https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/ are created to display the summary of a variable. A box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. [18] https://builtin.com/data-science/boxplot The x-axis denotes the data to be plotted while the y-axis shows the frequency distribution. Boxplots can tell you about your outliers and their values, if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed. dot, cross or diamond symbol is present inside the box, this represents the mean of the data. Outliers are easily visible in this type of plot.
#
# ![Box plot](https://th.bing.com/th/id/OIP.vbbq2ZjNjfgOX0DuVP23oQHaDG?rs=1&pid=ImgDetMain)
#
# * Countplot is used to show the counts of observations in each *categorical* bin usin bars.[19] https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html
#
# * Pie charts are proportional representation of numerical data of a variable, useful for displaying how a particular selection is in proportion to the larger whole. [20] https://www.greenprophet.com/2022/08/what-are-pie-charts-used-for/

# %% [markdown]
# 1. sex: as this is a categorical variable, an approriate plot would be a pie chart to visualise frequency of each species.

# %%
plt.figure(figsize=(4,4))
plt.pie(df['species'].value_counts(), labels=df['species'].unique(), colors=['green', 'yellow', 'red'])
plt.title('Species Distribution')
plt.show()

# %% [markdown]
# 2. island: as this is a categorical variable, an approriate plot would be a bar chart visualise frequency of each island.

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='island', data=df, palette=['green', 'yellow', 'red'])
plt.title('Island Frequency')
plt.show()

# %% [markdown]
# 3. bill_length_mm: this is a numerical and continuous variable so a histogram would be an appropriate plot to show the distribution of the variable

# %%
sns.histplot(x='bill_length_mm', data=df, bins=20, color='brown')
plt.title('Culmen Length Distribution')
plt.show()

# %% [markdown]
# 4. bill_depth_mm: this is a numerical and continuous variable so a histogram would be an appropriate plot to show the distribution of the variable

# %%
sns.histplot(x='bill_depth_mm', data=df, bins=20, color='pink')
plt.title('Culmen Depth Distribution')
plt.show()

# %% [markdown]
# 5. flipper_length_mm: this is a numerical and continuous variable so a histogram would be an appropriate plot to show the distribution of the variable

# %%
sns.histplot(x='flipper_length_mm', data=df, bins=20, color='pink')
plt.title('Culmen Depth Distribution')
plt.show()

# %% [markdown]
# 6. body_mass_g: this is a numerical and continuous variable but it is also a ratio variable, but a histogram would still be an appropriate plot to show the distribution of the variable

# %%
sns.histplot(x='body_mass_g', data=df, bins=20, color='gray')
plt.title('Body Mass Distribution')
plt.show()

# %% [markdown]
# 7. sex: this is a categorical variable and a histogram would  be an appropriate plot to show the distribution of the variable

# %%
sns.countplot(x='sex', data=df, palette=['lightblue', 'lightpink'])
plt.title('Sex Frequency')
plt.show()

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Pairplots are very useful for analysing data. pairplots visualise data to show relationships between variables. By using hue we can plot different values of a categorical variables by different colurs. Pairplot is a module of seaborn library. [21] https://medium.com/analytics-vidhya/pairplot-visualization-16325cd725e6

# %%
sns.pairplot(df, hue = 'species')
plt.show()

# %%
sns.histplot(data=df, x="bill_length_mm")
plt.show()

# %%
# Display the unique species
print(df['species'].unique())

# Display the unique islands
print(df['island'].unique())

# Display the unique species
print(df['sex'].unique())
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']
# ['Torgersen' 'Biscoe' 'Dream']
# ['Male' 'Female']

# %% [markdown]
# # References
# * [1] https://stackoverflow.com/questions/13366830/collatz-conjecture-sequence
# * [2] https://statisticseasily.com/quantitative-vs-qualitative/
# * [3] https://en.wikipedia.org/wiki/Continuous_or_discrete_variable#:~:text=A%20continuous%20variable%20is%20a%20variable%20whose%20value,can%20take%20on%20any%20value%20in%20that%20range.
# * [4] https://www.scribbr.com/statistics/levels-of-measurement/
# * [5] https://www.questionpro.com/blog/categorical-data-vs-numerical-data/
# * [6] https://libanswers.lib.miamioh.edu/stats-faq/faq/343638#:~:text=Nominal%20and%20ratio%20data%20types%20are%20both%20used,types%20are%20both%20used%20to%20describe%20numeric%20variables.
# * [7]  https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html The frequency of each species can be captured and assigned when synthesising new data. https://www.sharpsightlabs.com/blog/numpy-random-choice/
# * [8] https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html
# * [9] https://www.sharpsightlabs.com/blog/numpy-random-choice/
# * [10] https://byjus.com/maths/binomial-distribution/
# * [11] https://byjus.com/maths/binomial-distribution/
# * [12] https://www.w3schools.com/python/numpy/numpy_random_normal.asp
# * [13] https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# * [14] https://www.w3schools.com/python/numpy/numpy_random_normal.asp
# * [15] https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# * [16] https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/
# * [17] https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/
# * [18] https://builtin.com/data-science/boxplot
# * [19] https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html
# * [20] https://www.greenprophet.com/2022/08/what-are-pie-charts-used-for/
# * [21] https://medium.com/analytics-vidhya/pairplot-visualization-16325cd725e6

# %% [markdown]
# ***
# # End
