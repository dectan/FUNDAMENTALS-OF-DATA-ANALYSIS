# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Introduction
#
# The Iris Dataset or Fisher's Iris dataset was introduced in 1936 by Ronald Fisher. It is also known as Anderson's Iris dataset as Edgar Anderson collected the data. This dataset contains measurements of sepal_length	sepal_width	petal_length petal_width & species, 150 samples of 3 species of flowers setosa, versicolor, and virginica. It is a much used dataset in machine learning and data analaysis/ data visualisaton.

# %% [markdown]
# ![Iris Flowers](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)

# %% [markdown]
# # Select, demonstrate, and explain the most appropriate summary statistics to describe each variable

# %% [markdown]
# When *sns.get_dataset_names()* code is run, I can see 'iris' dataset is a built in Seaborn. To select 'iris' dataset, code *df = sns.load_dataset('iris')* is run.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('iris')

# %% [markdown]
# Now that the dataset is available, I will view the dataset to ensure dataset has loaded correctly.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# I will use *.head* and *.tail* commands to view first and last 5 rows

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# By running [1] https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html *.describe()* I can see the following information for each variable in the dataset.
#
# 1. Count of each variable, this is the number of samples for each variable.
# 2. Mean of each variable, this is the average value across all values in the column. This is a good indicator of the central tendency of each variable.
# 3. Standard Deviation of each variable, this is the measure of how much each variable deviates away from the mean.
# 4. min of each variable, this is the smallest value measured for this variable.
# 5. 25% Percentile, this is used to determine the lower percentile of the variable
# 6. 50% Percentile, this is the same as the median value
# 7. 75% Percentile this is used to determine the upper percentile of the variable
# 8. max of each variable, this is the largest value measured for this variable.

# %% [markdown]
# For the numeric variables (Sepal.Length, Sepal.Width, Petal.Length, Petal.Width), we can use the mean, median, minimum, maximum, first quartile, and third quartile to summarize the central tendency and distribution of the variables.For the Species variable which is categorical the frequency count can be used to summarize the number and frequency of each category.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# There are also both qualitative and Quantative variables in this dataset. [2] https://statisticseasily.com/quantitative-vs-qualitative/ qualitative variables are categorical while quantative are numerical.
# From the *.info* code , I can see that 4 of the variables are numeric type with species variable being the only cateorical
#
# 1. sepal_length: a *numerical* & *quantative* variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations and for graphs.
# 2. sepal_width: a *numerical* & *quantative* variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations and for graphs.
# 3. petal_length: a *numerical* & *quantative* variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations and for graphs.
# 4. petal_width:  a *numerical* & *quantative* variable as it represents a measurable quantity that is expressed in numbers. This variable type can be used for mathematical operations and for graphs.
# 5. species: a *categorical* & *qualitative* variable that stores string which can be observed but not measured. String is default datatype for categorical variables in Pandas.

# %% [markdown]
# | sepal_length | sepal_width | petal_length | petal_width| species|
# | --- | --- | --- | --- | --- | --- |
# | numerical | numerical | numerical | numerical | categorical |
# | quantative | quantative | quantative | quantative |qualitative |
# | continuous | continuous | continuous | continuous | categorical |
# | interval scale | interval scale | interval scale | interval scale | nominal scale |

# %% [markdown]
# A  quantitive variable variable can be continuous or discrete. If its value is obtained by measuring it, then it is continuous.[3] https://en.wikipedia.org/wiki/Continuous_or_discrete_variable#:~:text=A%20continuous%20variable%20is%20a%20variable%20whose%20value,can%20take%20on%20any%20value%20in%20that%20range.
#
# There are 4 levels of measurement (Nominal, Ordinal, Interval and Ratio)[4] https://www.scribbr.com/statistics/levels-of-measurement/
#
# * Nominal: data can only be categorised
# * Ordinal: data can be categorised and ranked
# * Interval: the data can be categorized, ranked, and evenly spaced
# * Ratio: the data can be categorized, ranked, evenly spaced, and has a natural zero.
#
# 1. sepal_length: a *continuous* variable that can take on an uncountable an uncountable set of values. This type of variable is measured on the *interval* scale but there is no true zero point.
# 2. sepal_width: a *continuous* variable that can take on an uncountable an uncountable set of values. This type of variable is measured on the *interval* scale but there is no true zero point.
# 3. petal_length: a *continuous* variable that can take on an uncountable an uncountable set of values. This type of variable is measured on the *interval* scale but there is no true zero point.
# 4. petal_width: a *continuous* variable that can take on an uncountable an uncountable set of values. This type of variable is measured on the *interval* scale but there is no true zero point.
# 5. species: a *categorical* variable that can take on an uncountable an uncountable set of values. This type of variable is measured on the *nominal* scale. The values are only labels but there is no order between the rankings.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Select, demonstrate, and explain the most appropriate plot(s) for each variable

# %% [markdown]
# ### Brief overview of plots used
#
# * Histograms [5] https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/ are a fundamental tool in data visualisation and provides a graphical dispaly of the distribution of data.  They are commonly used when analyzing continuous data. The x- axis represents the bin ranges and the y-axis gives information on the frequency.
#
# * Box plots [6] https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/ are created to display the summary of a variable. A box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. [7] https://builtin.com/data-science/boxplot The x-axis denotes the data to be plotted while the y-axis shows the frequency distribution. Boxplots can tell you about your outliers and their values, if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed. dot, cross or diamond symbol is present inside the box, this represents the mean of the data. Outliers are easily visible in this type of plot.
#
# ![Box plot](https://th.bing.com/th/id/OIP.vbbq2ZjNjfgOX0DuVP23oQHaDG?rs=1&pid=ImgDetMain)
#
# * Countplot is used to show the counts of observations in each *categorical* bin usin bars.[8] https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html
#
# * Pie charts are proportional representation of numerical data of a variable, useful for displaying how a particular selection is in proportion to the larger whole. [9] https://www.greenprophet.com/2022/08/what-are-pie-charts-used-for/

# %% [markdown]
# ## 1. sepal_length
# As discussed above, sepal_length is a *continuous* variable. A suitable plot for this variable would be a histogram. A histogram will show the frequency of values and the shape of the distribution. A Box plot would also be an approriate plot to show median , quartiles and any outliers present

# %%
plt.hist(df['sepal_length'], bins=10)
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()

# %%
sns.boxplot(x='species', y='sepal_length', data=df, palette='Blues')
plt.title('Boxplot of Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('sepal_length')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 1. sepal_width
#
# As discussed above, sepal_width is a *continuous* variable. A suitable plot for this variable would be a histogram. A histogram will show the frequency of values and the shape of the distribution. A Box plot would also be an approriate plot to show median , quartiles and any outliers present

# %%
plt.hist(df['sepal_width'], bins=10)
plt.xlabel('Sepal width')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Width')
plt.show()

# %%
sns.boxplot(x='species', y='sepal_width', data=df, palette='Blues')
plt.title('Boxplot of Sepal Width by Species')
plt.xlabel('Species')
plt.ylabel('sepal_width')
plt.show()

# %% [markdown]
# ## 1. petal_length
# As discussed above, sepal_length is a *continuous* variable. A suitable plot for this variable would be a histogram. A histogram will show the frequency of values and the shape of the distribution. A Box plot would also be an approriate plot to show median , quartiles and any outliers present

# %%
plt.hist(df['petal_length'], bins=10)
plt.xlabel('Petal lenght')
plt.ylabel('Frequency')
plt.title('Histogram of Petal lenght')
plt.show()

# %%
sns.boxplot(x='species', y='petal_length', data=df, palette='Blues')
plt.title('Boxplot of Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('petal_length')
plt.show()

# %% [markdown]
# ## 1. petal_width
# As discussed above, petal_width is a *continuous* variable. A suitable plot for this variable would be a histogram. A histogram will show the frequency of values and the shape of the distribution. A Box plot would also be an approriate plot to show median , quartiles and any outliers present

# %%
plt.hist(df['petal_width'], bins=10)
plt.xlabel('Petal width')
plt.ylabel('Frequency')
plt.title('Histogram of Petal width')
plt.show()

# %%
sns.boxplot(x='species', y='petal_width', data=df, palette='Blues')
plt.title('Boxplot of Petal Width by Species')
plt.xlabel('Species')
plt.ylabel('petal_width')
plt.show()

# %% [markdown]
# ## species:
# This a *categorical* variable that can be summarisec bu its frequency and proportion. For this reason a bar chart and  pie chart would be suitable plots for this variable.

# %%
#create a bar chart of species
sns.countplot(x='species', data=df, palette='Blues')
plt.title('Bar Chart of Species')
plt.xlabel('Species')
plt.ylabel('Count')
#plt.legend()
plt.show()

# %%
#create a pie chart of species

plt.pie(df['species'].value_counts(), colors=['steelblue', 'lightblue', 'skyblue'], autopct='%1.1f%%')
plt.title('Pie Chart of Species')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# https://chartio.com/learn/charts/what-is-a-scatter-plot/
# To visualise relationship between variables, a scatter plot is common used. These type of plot are useful for exploring the correlation , clustering outliers and trends
#
# ![Iris Flowers](https://chartio.com/assets/58c93c/tutorials/charts/scatter-plots/6165e528928b3c24a0fcfe14db25a0e53c917f8ec22b5bd75a6ee9f4e436004b/scatter-plot-example-2.png)

# %% [markdown]
# ![Iris Flowers](https://chartio.com/assets/df7151/tutorials/charts/scatter-plots/70dc1367416b6315d46b05a0c29cfd17e15649afc0ffc03d3b3d23891eba0125/scatter-plot-example-3.png)

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('Sepal Length v. Sepal Width')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='petal_length', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('Sepal Length v. Petal_Length')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='petal_width', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('Sepal Length v. Petal width')
plt.xlabel('sepal_length')
plt.ylabel('petal_width')
plt.show()

# %%
sns.scatterplot(x='sepal_width', y='petal_length', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('sepal_width v petal_length')
plt.xlabel('sepal_width')
plt.ylabel('petal_length')
plt.show()

# %% [markdown]
# https://medium.com/analytics-vidhya/pairplot-visualization-16325cd725e6
#
# Pairplots are very useful for analysing data. pairplots visualise data to show relationships between variables. By using hue we can plot different values of a categorical variables by different colurs. Pairplot is a module of seaborn library

# %%
sns.pairplot(df, hue= 'species')
plt.show()

# %% [markdown]
# # Conclusion
# The Iris dataset is well documented and consists of measurements of Sepal Lenght,Seapl Width,Petal Lenght & Petal Width for three different species;
#
# Iris-setosa
# Iris-versicolor
# Iris-virginica
# This dataset can be used to build classification model to predict the species based on its measurements. By visualising the data, each species and measurements can be easily interrogated. Visualising the data also shows the distribution of dat points for each species.The following conlusions are the most interesting I have found over the course of this prohect
#
# The Petal measurements are typically more useful in identifying species compared to sepal measurements
# The Setosa species is easiest to identify due to smaller size
# The Versicolr & Virginica species are hardest to identify

# %% [markdown]
# # References
# [1] https://pandas.pydata.org/pandasdocs/stable/reference/api/pandas.DataFrame.describe.html
# [2] https://statisticseasily.com/quantitative-vs-qualitative/
# [3] https://en.wikipedia.org/wiki/Continuous_or_discrete_variable#:~:text=A%20continuous%20variable%20is%20a%20variable%20whose%20value,can%20take%20on%20any%20value%20in%20that%20range.
# [4] https://www.scribbr.com/statistics/levels-of-measurement/
#
# [5] https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/
# [6] https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/
# [7] https://builtin.com/data-science/boxplot
# [8] https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html
# [9] https://www.greenprophet.com/2022/08/what-are-pie-charts-used-for/
