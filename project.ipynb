# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Introduction
#
# The Iris Dataset or Fisher's Iris dataset was introduced in 1936 by Ronald Fisher. It is also known as Anderson's Iris dataset as Edgar Anderson collected the data. From researching this dataset, I found that two out of three species were collected in same Peninsula, and picked on the same day, and also measured at the same time using the same apparatus. This dataset contains measurements of sepal_length	sepal_width	petal_length	petal_width	& species, 150 samples of 3 species of flowers setosa, versicolor, and virginica. It i a much used dataset in machine learning and data analaysuis/ data visualisaton

# %% [markdown]
# ![Iris Flowers](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)

# %%
#sns.get_dataset_names()
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Initial 5 rows using .head() function

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Last 5 rows using .tail() function

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# df.describe() displays the following onformation
# 1.Count of each column
# 2.Mean of each column
# 3.Standard Deviation of each colum
# 4.min of each colum
# 5.25% Percentile
# 6.50% Percentile
# 7.75% Percentile
# 8.max

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# adding pairplot using seaborn

# %%
sns.pairplot(df, hue= 'species')
plt.show()

# %%
plt.hist(df['sepal_length'], bins=10)
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()

# %%
plt.hist(df['sepal_width'], bins=10)
plt.xlabel('Sepal width')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Width')
plt.show()

# %%
plt.hist(df['petal_length'], bins=10)
plt.xlabel('Petal lenght')
plt.ylabel('Frequency')
plt.title('Histogram of Petal lenght')
plt.show()

# %%
plt.hist(df['petal_width'], bins=10)
plt.xlabel('Petal width')
plt.ylabel('Frequency')
plt.title('Histogram of Petal width')
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('Sepal Length v. Sepal Width')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='petal_length', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('Sepal Length v. Petal_Length')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='petal_width', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('Sepal Length v. Petal width')
plt.xlabel('sepal_length')
plt.ylabel('petal_width')
plt.show()

# %%
sns.scatterplot(x='sepal_width', y='petal_length', data=df, hue = "species",palette = ["green","blue","yellow"])
plt.title('sepal_width v petal_length')
plt.xlabel('sepal_width')
plt.ylabel('petal_length')
plt.show()

# %%
sns.boxplot(x='species', y='sepal_length', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Sepal Lenght by Species")
#plt.legend()
plt.show()

# %%
sns.boxplot(x='species', y='sepal_width', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Sepal Width by Species")
#plt.legend()
plt.show()

# %%
sns.boxplot(x='species', y='petal_length', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Petal Length by Species")
#plt.legend()
plt.show()

# %%
sns.boxplot(x='species', y='petal_width', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Petal Width by Species")
#plt.legend()
plt.show()

# %% [markdown]
# Discuss : Sepal Width

# %%
df['sepal_width'].describe()
# Out:
# count    150.000000
# mean       3.057333
# std        0.435866
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_width, dtype: float64

# %%
df.groupby('species')['sepal_width'].describe()
# Out:
#             count   mean       std  min    25%  50%    75%  max
# species
# setosa       50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
sns.boxplot(x='species', y='sepal_length', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Sepal Length")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot(x='species', y='sepal_width', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Sepal Width")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot(x='species', y='petal_length', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Petal Length")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot(x='species', y='petal_width', data=df)
plt.xlabel("Species")
plt.ylabel("Value")
plt.title("Petal Width")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
r = np.corrcoef(df["sepal_width"],df["sepal_length"])
r
# Out:
# array([[ 1.        , -0.11756978],
#        [-0.11756978,  1.        ]])

# %%
setosaDf = df.loc[df.loc[:,"species" ]== "setosa"]
versiDf = df.loc[df.loc[:,"species" ]== "versicolor"]
virgiDf = df.loc[df.loc[:,"species" ]== "virginica"]

# %%
r = np.corrcoef(setosaDf["sepal_width"],setosaDf["sepal_length"])
r
# Out:
# array([[1.        , 0.74254669],
#        [0.74254669, 1.        ]])

# %%
r = np.corrcoef(versiDf["sepal_width"],versiDf["sepal_length"])
r
# Out:
# array([[1.        , 0.52591072],
#        [0.52591072, 1.        ]])

# %%
r = np.corrcoef(virgiDf["sepal_width"],virgiDf["sepal_length"])
r
# Out:
# array([[1.        , 0.45722782],
#        [0.45722782, 1.        ]])

# %%
from scipy.fft import fft, fftfreq

import scipy.fft
# Read the dataset from a CSV file
#df = pd.read_excel('C02 Nature Paper.xlsx',sheet_name='3.  Composite CO2' ,skiprows=range(6))

# Select the column with CO2 (ppmv) values
y = df['petal_width']
y = np.ascontiguousarray(y)

# %%
yf = fft(y) # Frequency spectrum
xf = fftfreq(y.size)

# %%
plt.plot(xf, np.abs(yf)) # Plot the magnitude of the spectrum
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the iris dataset from scikit-learn
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data # Features
y = iris.target # Labels
feature_names = iris.feature_names # Feature names
target_names = iris.target_names # Class names


# Plot the correlation matrix of the features
sns.heatmap(df.corr(), annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# # Conclusion
# The Iris dataset is well documented and consists of measurements of Sepal Lenght,Seapl Width,Petal Lenght & Petal Width for three different species;
#
# Iris-setosa
# Iris-versicolor
# Iris-virginica
# This dataset can be used to build classification model to predict the species based on its measurements. By visualising the data, each species and measurements can be easily interrogated. Visualising the data also shows the distribution of dat points for each species.The following conlusions are the most interesting I have found over the course of this prohect
#
# The Petal measurements are typically more useful in identifying species compared to sepal measurements
# The Setosa species is easiest to identify due to smaller size
# The Versicolr & Virginica species are hardest to identify
